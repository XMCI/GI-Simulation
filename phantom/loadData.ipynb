# %% [markdown]
# ## 3D密堆积小球读取

# %%
import numpy as np
import matplotlib.pyplot as plt
# import simple_slice_viewer as ssv
# import SimpleITK as sikt

data = np.load('Sph_40.0um_0.4_40.npz')
print('npz文件保存的文件包括: ', data.files) # 打印全部文件名
# Out:
# npz文件保存的文件包括:  ['Sph', 'dx', 'gap', 'slice_thickness', 'total_thickness', 'N_slice']

# %%
print(data['total_thickness'])
Sph = data['Sph'][7]
plt.imshow(Sph , cmap='gray')
plt.colorbar()
# Out:
# 0.00023999999999999998

# %%
plt.plot(Sph[2000, :])
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3951230/1540777555.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
